# %% [markdown]
# <a href="https://colab.research.google.com/github/zjzsu2000/CMPE258/blob/master/assignment2/download.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Creating dataset from Google Images

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/"
base_dir = root_dir + 'CMPE258/assignment2/'
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Get a list of URLs

# %% [markdown]
# ### Search and scroll of "panda","bear","lion","tiger","dog","cat","duck"
# And download to csv files.
#
# using javascript command
# urls=Array.from(document.querySelectorAll('.rg_i')).map(el=> el.hasAttribute('data-src')?el.getAttribute('data-src'):el.getAttribute('data-iurl'));
#
# document.body.innerHTML = `<a href="data:text/csv;charset=utf-8,${urls.join('\n')}" download="links.csv">download urls</a>`;

# %% [markdown]
# ### Create directory and upload urls file

# %%
folder1 = 'panda'
file1 = 'panda.csv'

# %%
folder2 = 'bear'
file2 = 'bear.csv'

# %%
folder3 = 'lion'
file3 = 'lion.csv'

# %%
folder4='tiger'
file4="tiger.csv"

# %%
folder5 = 'dog'
file5 = 'dog.csv'

# %%
folder6 = 'cat'
file6 = 'cat.csv'

# %%
folder7 = 'duck'
file7 = 'duck.csv'

# %%
path = Path(base_dir + 'data')
dest1 = path/folder1
dest1.mkdir(parents=True, exist_ok=True)
dest2 = path/folder2
dest2.mkdir(parents=True, exist_ok=True)
dest3 = path/folder3
dest3.mkdir(parents=True, exist_ok=True)
dest4 = path/folder4
dest4.mkdir(parents=True, exist_ok=True)
dest5 = path/folder5
dest5.mkdir(parents=True, exist_ok=True)
dest6 = path/folder6
dest6.mkdir(parents=True, exist_ok=True)
dest7 = path/folder7
dest7.mkdir(parents=True, exist_ok=True)

# %%
path.ls()
# Out:
# [PosixPath('/content/gdrive/My Drive/CMPE258/assignment2/data/panda'),
#  PosixPath('/content/gdrive/My Drive/CMPE258/assignment2/data/bear'),
#  PosixPath('/content/gdrive/My Drive/CMPE258/assignment2/data/lion'),
#  PosixPath('/content/gdrive/My Drive/CMPE258/assignment2/data/tiger'),
#  PosixPath('/content/gdrive/My Drive/CMPE258/assignment2/data/cat'),
#  PosixPath('/content/gdrive/My Drive/CMPE258/assignment2/data/duck'),
#  PosixPath('/content/gdrive/My Drive/CMPE258/assignment2/data/dog'),
#  PosixPath('/content/gdrive/My Drive/CMPE258/assignment2/data/models'),
#  PosixPath('/content/gdrive/My Drive/CMPE258/assignment2/data/export.pkl')]

# %% [markdown]
# ## Download images

# %%
classes = ['panda','bear','lion',"tiger","dog","cat","duck"]

# %%
import pandas as pd

# %%
#Reading in the data as a Pandas dataframe to skip_blank_lines
urls1 = pd.read_csv(dest1/file1,skip_blank_lines=True)
urls1.shape
# Out:
# (419, 1)

# %%
urls1.to_csv(dest1/file1,index=None)#write back to file

# %%
download_images(dest1/file1, dest1, max_pics=500)

# %%
#Reading in the data as a Pandas dataframe to skip_blank_lines
urls2 = pd.read_csv(dest2/file2,skip_blank_lines=True)
urls2.shape
# Out:
# (659, 1)

# %%
urls2.to_csv(dest2/file2,index=None)#write back to file

# %%
download_images(dest2/file2, dest2, max_pics=650)

# %%
#Reading in the data as a Pandas dataframe to skip_blank_lines
urls3 = pd.read_csv(dest3/file3,skip_blank_lines=True)
urls3.shape
# Out:
# (602, 1)

# %%
urls3.to_csv(dest3/file3,index=None)#write back to file

# %%
download_images(dest3/file3, dest3, max_pics=600)

# %%
urls4 = pd.read_csv(dest4/file4,skip_blank_lines=True)
urls4.shape
# Out:
# (425, 1)

# %%
urls4.to_csv(dest4/file4,index=None)#write back to file

# %%
download_images(dest4/file4, dest4, max_pics=425)

# %%
urls5 = pd.read_csv(dest5/file5,skip_blank_lines=True)
urls5.shape
# Out:
# (667, 1)

# %%
urls5.to_csv(dest5/file5,index=None)#write back to file

# %%
download_images(dest5/file5, dest5, max_pics=666)

# %%
urls6 = pd.read_csv(dest6/file6,skip_blank_lines=True)
urls5.shape
# Out:
# (667, 1)

# %%
urls6.to_csv(dest6/file6,index=None)#write back to file

# %%
download_images(dest6/file6, dest6, max_pics=666)

# %%
urls7 = pd.read_csv(dest7/file7,skip_blank_lines=True)
urls7.shape
# Out:
# (622, 1)

# %%
urls7.to_csv(dest7/file7,index=None)#write back to file

# %%
download_images(dest7/file7, dest7, max_pics=622)

# %% [markdown]
# verify_images,remove can't open ones

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=666)
# Out:
# panda
# bear
# lion
# tiger
# dog
# cat
# duck

# %% [markdown]
# ## View data

# %%
path
# Out:
# PosixPath('/content/gdrive/My Drive/CMPE258/assignment2/data')

# %%
img = open_image(path/'tiger'/'00000021.jpg')
img
# Out:
# Image (3, 185, 273)

# %%
img = open_image(path/'lion'/'00000021.jpg')
img
# Out:
# Image (3, 183, 275)

# %%
img = open_image(path/'dog'/'00000021.jpg')
img
# Out:
# Image (3, 159, 317)

# %%
img = open_image(path/'cat'/'00000021.jpg')
img
# Out:
# Image (3, 183, 275)

# %%
img = open_image(path/'panda'/'00000021.jpg')
img
# Out:
# Image (3, 194, 259)

# %%
img = open_image(path/'duck'/'00000021.jpg')
img
# Out:
# Image (3, 225, 224)

# %%
img = open_image(path/'bear'/'00000021.jpg')
img
# Out:
# Image (3, 168, 300)

# %%
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
train = ImageDataGenerator().flow_from_directory(directory=path, target_size=(48,48))
# Out:
# Found 4023 images belonging to 7 classes.
